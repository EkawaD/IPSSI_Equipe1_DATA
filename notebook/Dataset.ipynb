# %% [markdown]
# # Dataset young survey

# %% [markdown]
# Notebook du projet Dataset young survey basé sur le repo kaggle suivant : https://www.kaggle.com/miroslavsabo/young-people-survey

# %% [markdown]
# ## Requête n°1 : Hello darkness my old friend...
